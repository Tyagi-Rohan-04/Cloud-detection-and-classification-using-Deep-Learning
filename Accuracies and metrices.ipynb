# %%
import matplotlib.pyplot as plt
import numpy as np

algo_names = np.array(["ResNet50", "VGG19", "Xception", "YOLOv8"])
accuracies = np.array([48, 85, 98, 99])

plt.bar(algo_names, accuracies, color = "#aa3b53")
plt.show()
